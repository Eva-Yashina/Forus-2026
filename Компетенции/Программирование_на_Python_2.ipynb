# %% [markdown]
# #Задание первое
#
# 1. Скопируйте данный ноутбук к себе (Файл / Создать копию на диске)
# 2. Решите задачу, создавая новые блоки "Код". Все блоки должны быть запущены и результаты выведены!
# 3. Опубликуйте решение по ссылке ("Поделиться" сверху справа)
# 4. Отправьте ссылку в качестве решени
#
# Внимание! Не изменяйте блок кода ниже, перед началом решения запустите его. Решение пишите в отдельном окне. Решение должно быть таким, что подставив в массив другие значения, обработка пройдет корректно и без ошибок.
#
# 1. Удалите из массива **arr1** все отрицательные элементы. Выведете количество получившихся элементов массива.
# 2. Обработайте каждый элемент массива **arr2**, удалив "двойные пробелы", а также лишние пробелы в начале и в конце строки (пробел между словами должен остаться).
# 3. Найдите сумму отрицательных значений массива **arr3**.
# 4. Уберите повторы из массива **arr3**.
# 5. Упорядочите полученный массив **arr3** по возрастанию. Выведете 10 самых больших значений.
# 6. В полученном массиве **arr3** найдите сумму элементов, индексы которых находятся в последовательности Фибоначчи (без повторений, то есть первый элемент должен посчитаться 1 раз).
#
# Результат каждого задания выведете на экран.
#
# **Последовательность Фибоначчи**
#
# $f_0 = 0$
#
# $f_1 = 1$
#
# $f_{n} = f_{n-1} + f_{n-2}$.
#
# Таким образом, последовательность Фибоначчи: 0 -> 1 -> 1 -> 2 -> 3 -> 5 -> 8 -> 13 -> ...

# %%
#Исходные данные (запустите эту ячейку)
arr1 = [3, 2, 2, 3, 1, 1, 15, 14, 3, 6, -1, 5, -6, 0, 4]
arr2 = ["Король     пики", "дАМа   крести", "   Туз     черви", "            Валет буби  "]
arr3 = [-146, -72, 295, 71, -50, -158, 149, -281, -92, 267, 18, 23, 300, -280, -207, 50, 145, -139, -211, -144, 132, -128, 147, -85, 103, 269, 279, -292, -145, -268, 160, -93, 99, -282, 71, 45, -146, 56, 256, -45, 286, 28, 34, -188, -249, -53, -86, 13, 283, 133, 280, 215, 237, -70, -51, 269, 57, -258, -205, -264, 106, 234, 151, -55, 177, 294, -169, -255, -44, -54, -64, 190, -288, -252, 244, -79, 185, 155, -120, 143, 140, 2, 123, 82, 110, -182, 222, -109, 72, -185, 18, -134, -103, -87, -54, 290, 212, 93, -34, -223, -230, 225, 62, -284, -75, -90, -251, -121, 89, -36, 245, -114, 267, -36, -79, 200, -27, -292, 236, -289, -93, 288, -47, 134, 247, 237, 15, 55, -67, -179, 89, -228, -43, -1, -127, -295, -99, -155, -32, -206, 175, 156, 108, 163, 10, -25, -3, -243, 300, -72, 252, -117, -262, -215, -125, -205, -188, -147, -151, 148, -18, 266, -215, -40, -252, 300, 177, 237, 145, 121, -18, 271, -239, -127, -35, -100, -233, -129, -77, -13, -18, -125, 27, 264, 75, -163, 213, 124, 290, 87, 20, -185, -108, 174, -108, 224, 113, -201, 130, 24, -204, 174, 115, -184, 0, -34, 28, -296, -269, -287, -63, 21, -257, 63, -166, 27, 8, -84, 272, 194, -161, 75, 173, 227, 16, 91, 90, -36, -71, -212, 51, 204, 138, 292, -29, 52, -98, -85, 37, -66, -44, 173, -265, 251, 127, 195, 255, 123, 204, -268, -35, 172, -160, -22, -219, 102, -51, 61, -134, -38, -160, -64, 72, 87, 73, 296, -197, -67, -179, -12, -194, 199, -300, -48, -137, 272, 8, -177, 152, 197, 252, 49, 87, 107, -297, -144, 190, -281, -77, -132, 296, -82, 268, -291, -177, 288, 37, 14, -17, 24, -257, 233, -248, 248, -157, -250, -210, 71, -19, -210, 25, -199, 154, 297, 259, -5, -77, -53, 299, 2, -138, 127, 91, 195, -70, 88, 29, -131, 118, 0, 261, 299, 7, -64, 45, 267, 290, -216, 81, 185, -133, 51, -145, 133, 21, -73, -116, 67, 10, -266, 245, 30, 207, 112, 45, 83, -164, -126, -194, -21, 53, -202, 191, -152, 20, -290, 225, -206, 288, -85, 146, -136, 239, -120, -276, -51, 5, 220, 91, 295, 85, 50, -211, -234, -270, -180, 47, 252, -119, 6, 119, -64, 297, -66, -207, 156, -294, 176, -70, -157, -121, 253, -162, 234, 165, -29, -153, -190, 0, -145, -151, 25, -89, 23, -152, -258, -135, -57, -118, 95, 273, -239, 202, -219, -83, 166, 192, 122, -114, 242, -270, -4, -294, -166, -102, 93, -25, -188, 224, 174, -186, -54, 203, 61, -153, 276, -256, -208, 26, -276, 80, -211, 3, 37, -20, -54, -63, -291, -285, -208, 211, -11, 214, 72, -274, -34, -39, 71, -243, 216, 188, 14, -206, 105, -267, -270, -250, -213, 201, -240, 274, 294, 102, 134, -115, -169, 2, -145, -68, -137, -172, 286, -103, 165, -139, 296, 33, -226, -49, 288, 252, -179, 242, -144, 278, 83, -299, -270, -50, -25, 6, -288, -54, -136, 231, -270, -40, 172, 227, -127, 16, 151, -82, -246, 125, -300, -249, -231, 235, 210, -229, 149, 295, -58, 277, 122, -72, 107, 247, 54, 289, 80, -197, -87, 12, -149, 160, 220, 125, 218, 230, -64, 249, -294, 272, -228, -171, -147, -47, 58, -109, 160, -154, -95, 230, -58, -122, 179, -226, -276, -33, 114, -297, -211, 236, 123, -180, -57, -106, 276, 10, 48, -82, -69, -246, -244, -297, 173, 289, 252, 87, 59, 167, -227, 169, 41, -121, -223, 22, -222, 61, -88, -138, -78, -14, -179, 268, -204, -120, -133, -286, 120, 55, 29, -190, -47, 174, -27, 35, -276, -187, 208, 68, -94, -142, 263, 228, -40, 9, 14, -87, -48, -113, -27, -287, 241, 15, -61, -260, -37, 55, -261, -86, -109, -148, 122, -32, -46, -246, 288, -230, -90, -244, -65, -263, 179, -3, 24, -145, 251, 144, -171, 296, 154, -6, -172, -1, -28, -17, -108, -85, -27, -53, -108, 213, 172, 165, -17, -257, -66, 93, 40, 186, -43, -187, -128, 25, -41, -186, 52, -189, 129, 288, -181, 178, 201, -259, 280, 173, 66, -35, 44, -142, 195, -292, 235, 13, -213, 103, 254, 127, -73, -294, 100, -27, 223, -149, 252, 249, 128, 271, 185, 151, -227, 37, -109, 93, -84, -92, -64, 185, -96, 145, -281, -42, 287, -228, 144, -140, -155, -119, 293, -135, 41, 95, -55, -154, 41, 213, -195, 16, 144, 3, -26, 246, -182, 230, 233, 240, -163, -225, -264, -1, -138, -145, -59, 270, 164, 38, 123, -170, 250, -68, 15, -138, 81, 198, -26, 212, -99, -176, -151, 233, 183, 4, 37, 112, -157, 101, 295, -221, 141, 162, -204, 176, 294, 75, -49, 190, 174, -173, 43, 214, -195, -29, 274, -117, 133, -47, -122, 289, 170, 235, -166, -48, 122, 175, 110, 273, 143, 9, 293, -52, -115, 98, -20, -202, -297, -142, 15, -134, 68, -148, -165, 59, 162, -154, -55, -30, -85, -66, -39, 230, 43, -261, 66, 15, 279, -80, 124, -198, 29, -31, -41, 254, 35, 215, -139, -138, 51, 298, -294, -297, 170, 263, -248, 197, 238, -23, -126, -246, -221, 29, -87, 35, -124, 249, 211, -282, -257, 56, 204, 77, 261, 274, 2, -230, 187, 234, -160, -30, -271, 4, 78, 192, 145, 90, -278, 259, 157, -43, 77, 103, -62, -96, 46, 124, -180, -233, 251, 232, -276, 9, -34, -14, -208, 211, 241, -34, -9, -235, 31, 274, -297, -68, 61, 111, 19, 244, -269, -210, -112, -66, -214, -177, 299, -90, -263, -215, 106, -213, 76, -101, -156, -162, 296, 299, 154, -56, -126, -3, -7, 38, 221, -259, -16, -187, -148, -234, 7, -240, -226, -112, -232, -286, -158, -292, -166, 16, 225, -101, 92, -76, 276, -64, 271, 141, -164, -284, -39, 280, -215, 102, 77, 178, 61, -280, 188, -274, -189, 195, -53, -227, -200, -5, 229, -49, -137, 178, -127]

# %%
#Решение
#1
arr1 = [x for x in arr1 if x >= 0]
print("1 ", len(arr1))

#2

arr2 = [' '.join(s.split()) for s in arr2]
print("2 ",arr2)

#3
sum_neg = sum(x for x in arr3 if x < 0)
print("3 ",sum_neg)

#4
arr3_unique = list(set(arr3))
print("4 ",len(arr3_unique))

#5
arr3_sorted = sorted(arr3_unique)
top_10 = arr3_sorted[-10:] if len(arr3_sorted) >= 10 else arr3_sorted
print("5 ",top_10)

#6

max_index = len(arr3_sorted) - 1
fib = set()
a, b = 0, 1
while a <= max_index:
    fib.add(a)
    a, b = b, a + b
sum_fib = sum(arr3_sorted[i] for i in fib if i <= max_index)
print("6 ", sum_fib)
# Out:
# 1  13
# 2  ['Король пики', 'дАМа крести', 'Туз черви', 'Валет буби']
# 3  -75578
# 4  485
# 5  [290, 292, 293, 294, 295, 296, 297, 298, 299, 300]
# 6  -2970

# %% [markdown]
# #Задание второе
#
# В строке описан JSON, полученный из некоторой базы.
#
# При помощи библиотеки json реализуйте парсинг данной строки и выведете следующую информацию:
# 1. Общая сумма баланса всех перечисленных аккаунтов (поле "balance");
# 2. Средний возраст, указанный в этих аккаунтах (поле "age");
# 3. Сколько всего различных людей в этой базе (поле "name", а также "friends" / "name")?
# 4. Какой из перечисленных аккаунтов зарегистрировался раньше остальных? (Поле "registered", воспользуйтесь библиотекой time)

# %%
#Исходные данные
data = '''
[
  {
    "_id": "65ae05f60317f58cbf241342",
    "index": 0,
    "guid": "59909ea0-cdef-468a-a7ab-95e478f98198",
    "isActive": true,
    "balance": "$1,023.29",
    "picture": "http://placehold.it/32x32",
    "age": 39,
    "eyeColor": "blue",
    "name": "Pearson Garner",
    "gender": "male",
    "company": "EXOPLODE",
    "email": "pearsongarner@exoplode.com",
    "phone": "+1 (924) 427-2937",
    "address": "899 Arlington Avenue, Dodge, Puerto Rico, 7191",
    "about": "Culpa dolor enim ullamco fugiat amet laborum proident. Do excepteur et velit proident pariatur ut proident aute nostrud laboris proident nostrud laboris eu. Excepteur quis tempor sint id deserunt. Nisi labore incididunt pariatur proident proident et duis sint eu do in. Adipisicing in elit magna reprehenderit incididunt laboris sit reprehenderit adipisicing in occaecat eu cupidatat. Ex anim nostrud voluptate consequat consectetur. Cupidatat ex laborum veniam est et officia ullamco ad nisi consectetur ipsum eiusmod.",
    "registered": "2019-09-26T01:23:40 -08:00",
    "latitude": -68.359558,
    "longitude": -127.066084,
    "tags": [
      "commodo",
      "ut",
      "commodo",
      "deserunt",
      "est",
      "occaecat",
      "excepteur"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Ramirez Malone"
      },
      {
        "id": 1,
        "name": "Sanford Byers"
      },
      {
        "id": 2,
        "name": "Rosalinda Whitehead"
      }
    ],
    "greeting": "Hello, Pearson Garner! You have 9 unread messages.",
    "favoriteFruit": "apple"
  },
  {
    "_id": "65ae05f680c87011b876d39c",
    "index": 1,
    "guid": "587f37b2-139d-47ca-9eba-cca1503e4635",
    "isActive": false,
    "balance": "$2,321.46",
    "picture": "http://placehold.it/32x32",
    "age": 26,
    "eyeColor": "green",
    "name": "Cleveland Fletcher",
    "gender": "male",
    "company": "PAPRIKUT",
    "email": "clevelandfletcher@paprikut.com",
    "phone": "+1 (939) 468-3128",
    "address": "297 Furman Avenue, Harviell, Indiana, 991",
    "about": "Officia mollit id dolor duis. Esse dolor in et excepteur ullamco in cillum esse ex ex. Nulla reprehenderit fugiat mollit sit ullamco.",
    "registered": "2023-12-04T12:20:04 -08:00",
    "latitude": -67.917824,
    "longitude": 148.356888,
    "tags": [
      "elit",
      "sunt",
      "consequat",
      "cillum",
      "id",
      "est",
      "velit"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Maryellen Lamb"
      },
      {
        "id": 1,
        "name": "Patty Massey"
      },
      {
        "id": 2,
        "name": "Faith Vaughn"
      }
    ],
    "greeting": "Hello, Cleveland Fletcher! You have 10 unread messages.",
    "favoriteFruit": "apple"
  },
  {
    "_id": "65ae05f64e1e8c0cb42cbea8",
    "index": 2,
    "guid": "693ec992-9693-4acb-bff6-7f4f4f1b5560",
    "isActive": false,
    "balance": "$1,702.71",
    "picture": "http://placehold.it/32x32",
    "age": 28,
    "eyeColor": "blue",
    "name": "Todd Lyons",
    "gender": "male",
    "company": "DIGIPRINT",
    "email": "toddlyons@digiprint.com",
    "phone": "+1 (932) 515-3618",
    "address": "981 Tampa Court, Thornport, Maryland, 7268",
    "about": "Ipsum magna sunt magna dolore consequat et ullamco irure fugiat. Laboris laboris reprehenderit reprehenderit nostrud. Ex in aliqua veniam anim esse dolor exercitation sunt excepteur sunt. Incididunt ullamco amet et sunt do. Aute consequat dolor voluptate deserunt ut aliquip.",
    "registered": "2015-01-09T12:21:47 -08:00",
    "latitude": 86.291417,
    "longitude": -119.10069,
    "tags": [
      "consequat",
      "commodo",
      "aute",
      "sint",
      "fugiat",
      "reprehenderit",
      "deserunt"
    ],
    "friends": [
      {
        "id": 0,
        "name": "English Woodard"
      },
      {
        "id": 1,
        "name": "Petersen Lara"
      },
      {
        "id": 2,
        "name": "Latonya Case"
      }
    ],
    "greeting": "Hello, Todd Lyons! You have 10 unread messages.",
    "favoriteFruit": "apple"
  },
  {
    "_id": "65ae05f6e022ae12540a3e7a",
    "index": 3,
    "guid": "b6a6ee96-de95-4f27-96d6-87f7d1c37739",
    "isActive": true,
    "balance": "$2,448.51",
    "picture": "http://placehold.it/32x32",
    "age": 22,
    "eyeColor": "blue",
    "name": "Parrish Rojas",
    "gender": "male",
    "company": "DANCITY",
    "email": "parrishrojas@dancity.com",
    "phone": "+1 (884) 491-3460",
    "address": "414 Ebony Court, Emison, Nevada, 4582",
    "about": "Culpa commodo qui ipsum sint fugiat cillum eu. Consectetur occaecat magna ea incididunt nisi velit in aliquip dolore pariatur. Duis eu excepteur aute ut. Nisi labore esse ullamco commodo sunt id pariatur nostrud officia. Deserunt sunt ex Lorem sunt minim.",
    "registered": "2022-02-20T06:30:54 -08:00",
    "latitude": 88.000587,
    "longitude": -12.379392,
    "tags": [
      "incididunt",
      "magna",
      "duis",
      "tempor",
      "incididunt",
      "occaecat",
      "laboris"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Britt Maddox"
      },
      {
        "id": 1,
        "name": "Pearson Garner"
      },
      {
        "id": 2,
        "name": "Gay Noel"
      }
    ],
    "greeting": "Hello, Parrish Rojas! You have 6 unread messages.",
    "favoriteFruit": "apple"
  },
  {
    "_id": "65ae05f6a81f49224938a877",
    "index": 4,
    "guid": "00419f19-5d4b-44f2-89da-0414d33fd859",
    "isActive": true,
    "balance": "$3,881.10",
    "picture": "http://placehold.it/32x32",
    "age": 25,
    "eyeColor": "brown",
    "name": "Ana Osborne",
    "gender": "female",
    "company": "FLOTONIC",
    "email": "anaosborne@flotonic.com",
    "phone": "+1 (915) 540-3846",
    "address": "214 Nolans Lane, Helen, Illinois, 3894",
    "about": "Nisi anim officia laborum proident irure mollit consequat incididunt reprehenderit. Occaecat occaecat adipisicing irure adipisicing aliquip qui aliquip voluptate anim. Enim excepteur magna magna ad duis. Excepteur eu commodo culpa velit ex nulla occaecat culpa.",
    "registered": "2022-08-25T04:02:57 -08:00",
    "latitude": -8.441071,
    "longitude": -127.283627,
    "tags": [
      "excepteur",
      "qui",
      "sint",
      "exercitation",
      "fugiat",
      "voluptate",
      "commodo"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Carlene Rodriquez"
      },
      {
        "id": 1,
        "name": "Sargent Avila"
      },
      {
        "id": 2,
        "name": "Kent Downs"
      }
    ],
    "greeting": "Hello, Ana Osborne! You have 10 unread messages.",
    "favoriteFruit": "banana"
  },
  {
    "_id": "65ae05f6355f5c7818706d52",
    "index": 5,
    "guid": "6ebf80df-8a5e-422a-94ef-3bd5b3fdf54b",
    "isActive": false,
    "balance": "$3,551.49",
    "picture": "http://placehold.it/32x32",
    "age": 37,
    "eyeColor": "blue",
    "name": "Imelda Alexander",
    "gender": "female",
    "company": "COMTRAK",
    "email": "imeldaalexander@comtrak.com",
    "phone": "+1 (813) 504-2406",
    "address": "449 Guider Avenue, Herlong, Virginia, 1938",
    "about": "Non officia irure eiusmod irure anim laborum commodo exercitation commodo veniam in culpa. Laborum reprehenderit et qui magna ipsum ut esse ad veniam. Id mollit deserunt ut ex ea fugiat consequat culpa ea ex dolore amet Lorem. Non excepteur consectetur aliquip enim excepteur. Duis commodo dolor et velit cillum elit. Dolore sunt voluptate consequat mollit id consectetur sint enim id esse. Consequat qui voluptate culpa irure est deserunt sit deserunt enim tempor cupidatat excepteur.",
    "registered": "2014-08-31T07:36:09 -09:00",
    "latitude": 18.283175,
    "longitude": 151.690652,
    "tags": [
      "mollit",
      "exercitation",
      "amet",
      "enim",
      "sit",
      "quis",
      "cupidatat"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Parrish Rojas"
      },
      {
        "id": 1,
        "name": "Mejia Gordon"
      },
      {
        "id": 2,
        "name": "Mcleod Warren"
      }
    ],
    "greeting": "Hello, Imelda Alexander! You have 2 unread messages.",
    "favoriteFruit": "banana"
  }
]
'''

# %%
#Решение

import json
import time

accounts = json.loads(data)

#1
total_balance = sum(
    float(acc['balance'].replace('$', '').replace(',', ''))
    for acc in accounts
)

print(f"Общая сумма балансов: ${total_balance:,.2f}")

#2
ages = [acc['age'] for acc in accounts]
avg_age = sum(ages) / len(ages)
print(f"Средний возраст: {avg_age:.2f} лет")

#3
people = set()
for acc in accounts:
    people.add(acc['name'])
    for f in acc['friends']:
        people.add(f['name'])
print("Количество различных людей:", len(people))

#4
earliest = None
earliest_ts = None
for acc in accounts:
    dt_str = acc['registered'].split(' ')[0]
    t = time.strptime(dt_str, "%Y-%m-%dT%H:%M:%S")
    ts = time.mktime(t)
    if earliest_ts is None or ts < earliest_ts:
        earliest_ts = ts
        earliest = acc
print("Самый ранний аккаунт:")
print("Имя:", earliest['name'])
print("Дата регистрации:", earliest['registered'])
# Out:
# Общая сумма балансов: $14,928.56
# Средний возраст: 29.50 лет
# Количество различных людей: 22
# Самый ранний аккаунт:
# Имя: Imelda Alexander
# Дата регистрации: 2014-08-31T07:36:09 -09:00
